# %% [markdown]
# - **Tenga en cuenta que la calidad/legibilidad del código ES importante**
# - **Para cada pregunta incluya en prompt inicial empleado para generar el código**

# %% [markdown]
# **En exámen de la siguiente semana incluirá:**
#
# - Un ejercicio de extracción (JSON)
# - Preguntas relacionadas a los datos extraidos

# %%
import polars as pl

sales = pl.read_csv("sales.csv", try_parse_dates=True)
sales.head()
# Out:
# shape: (5, 18)
# ┌────────────┬─────┬──────────┬──────┬───┬────────────┬────────┬──────┬─────────┐
# │ Date       ┆ Day ┆ Month    ┆ Year ┆ … ┆ Unit_Price ┆ Profit ┆ Cost ┆ Revenue │
# │ ---        ┆ --- ┆ ---      ┆ ---  ┆   ┆ ---        ┆ ---    ┆ ---  ┆ ---     │
# │ date       ┆ i64 ┆ str      ┆ i64  ┆   ┆ i64        ┆ i64    ┆ i64  ┆ i64     │
# ╞════════════╪═════╪══════════╪══════╪═══╪════════════╪════════╪══════╪═════════╡
# │ 2013-11-26 ┆ 26  ┆ November ┆ 2013 ┆ … ┆ 120        ┆ 590    ┆ 360  ┆ 950     │
# │ 2015-11-26 ┆ 26  ┆ November ┆ 2015 ┆ … ┆ 120        ┆ 590    ┆ 360  ┆ 950     │
# │ 2014-03-23 ┆ 23  ┆ March    ┆ 2014 ┆ … ┆ 120        ┆ 1366   ┆ 1035 ┆ 2401    │
# │ 2016-03-23 ┆ 23  ┆ March    ┆ 2016 ┆ … ┆ 120        ┆ 1188   ┆ 900  ┆ 2088    │
# │ 2014-05-15 ┆ 15  ┆ May      ┆ 2014 ┆ … ┆ 120        ┆ 238    ┆ 180  ┆ 418     │
# └────────────┴─────┴──────────┴──────┴───┴────────────┴────────┴──────┴─────────┘

# %% [markdown]
# **Ejercicio 1**
#
# Filtrando solo los datos del año 2016, ¿cuáles son los 3 países que generaron el mayor beneficio total?

# %% [markdown]
# **Ejercicio 2**
#
# Para las ventas en Alemania realizadas en 2015, obtenga las ventas que superaron el promedio de su respectiva subcategoría.

# %% [markdown]
# **Ejercicio 3**
#
# Para la ventas del 2014, qué producto se ha vendido más en invierno por país?
