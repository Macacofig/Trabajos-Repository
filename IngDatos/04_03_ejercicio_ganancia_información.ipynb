# %% [markdown]
# ## Arboles de decisión - ganancia de información

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Cuál variable se debería emplear para comenzar a construir un árbol de decisión a partir de los anteriores ejemplos?

# %%
inf_inicial = cantidad_info(9/14, 5/14)
inf_inicial
# Out:
# 0.9402859586706311

# %% [markdown]
# ## ¿Se aprueba el préstamo?
#
# El objetivo es determinar si un cliente recibirá un préstamo basado en su historial.
#
# ```csv
# Empleado,Historial Crediticio,Ingresos,Aprobado (Clase)
# Sí,Bueno,Altos,Sí
# Sí,Malo,Altos,Sí
# No,Bueno,Altos,Sí
# No,Malo,Bajos,No
# No,Bueno,Bajos,No
# Sí,Malo,Bajos,Sí
# ```

# %%
# Qué variable se debería emplear para comenzar a construir un árbol de decisión a partir de los anteriores ejemplos?

# %% [markdown]
# ## Diagnóstico de Soporte Técnico
#
# Imagina que trabajas en IT y quieres automatizar si una computadora necesita reparación física o solo una actualización de software.
#
# ```csv
# Antigüedad,Enciende,Ruidos Raros,Reparación Física
# Vieja,Sí,Sí,Sí
# Nueva,Sí,No,No
# Vieja,No,No,Sí
# Nueva,No,Sí,Sí
# Nueva,Sí,No,No
# ```

# %%
# Qué variable se debería emplear para comenzar a construir un árbol de decisión a partir de los anteriores ejemplos?

# %% [markdown]
# # Referencias
#
# - [Aprendizaje basado en árboles de decisión](https://es.wikipedia.org/wiki/Aprendizaje_basado_en_%C3%A1rboles_de_decisi%C3%B3n)
