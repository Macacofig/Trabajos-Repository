# %% [markdown]
# **Extraer en un archivo CSV, los datos enmarcados en recuadros de color verde de cada función en la cartelera del Cine Center que inicia a partir de las 18.00**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import requests

response = requests.get("https://www.bolivia.com/cine/cine-center-cochabamba-s178")
response
# Out:
# <Response [200]>
