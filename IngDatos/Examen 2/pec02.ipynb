# %% [markdown]
# **Instrucciones**
# - Pueden apoyarse en búsquedas en internet, los notebooks o Gemini
# - Al finalizar, deberán enviar el notebook a jrocabado.t@ucb.edu.bo
#
# **Tenga en cuenta que la calidad/legibilidad del código ES importante**

# %% [markdown]
# **Integrates del grupo**
# - NOMBRE DEL ESTUDIANTE
# - NOMBRE DEL ESTUDIANTE
# - NOMBRE DEL ESTUDIANTE

# %% [markdown]
# ## Requerimientos
#
# Empleando JMESPath, extraer en un archivo `carts.csv` los siguientes datos:
#
# - id del carro
# - total del carro
# - discountedTotal del carro
# - userId
# - id del producto
# - title del producto
# - price del producto
# - quantity del producto
#
# De todos los carros de compra que tengan más de dos productos
#
# Luego, empleando Polars, obtener:
#
# 1. Un ranking de los productos más vendidos (descedente)
# 2. Los tres usuarios que más descuentos recibieron
#
#
# Fuente:
#
# https://dummyjson.com/carts
#
# **Criterios mínimos de calidad del código:**
# - Seguir los linemientos de programación de Python
# - Separar de manera gradual el qué del cómo (el número de niveles de abtracción depende de la complejidad de la tarea)
# - Incluir Type hints en las definiciones de las funciones y en el cuerpo de las funciones siempre que mejore la legibilidad del código
# - No mezclar español con inglés en el código.
# - Aplicar el principio de única responsabilidad, por ejemplo evitar: `guarda_datos_peliculas(page:BeautifulSoup)`
# - **No cometer los mismos errores que en la prueba anterior**.
# - **Es mejor realizar un trabajo parcial que entregar código que genera errores.**

# %% [markdown]
# **La espuesta debe incluir:**
#
# - El prompt para generar el código inicial
# - El código inicial generado por Gemini
# - El código corregido por el equipo

# %% [markdown]
# # Respuesta

# %% [markdown]
# ## Prompt

# %% [markdown]
# ## Código generado por Gemini empleando el prompt anterior

# %% [markdown]
# ## Código mejorado por el equipo
