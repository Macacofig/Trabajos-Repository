# %% [markdown]
# # Árboles de decisión
#
# Esta sección requiere la instalación de la librería [Scikit-learn](https://scikit-learn.org/stable/).

# %%
import polars as pl
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
df = pl.read_csv("diabetes.csv")
df.head()
# Out:
# shape: (5, 9)
# ┌─────────────┬─────────┬─────────────┬─────────────┬───┬─────────────┬────────────┬─────┬─────────┐
# │ Pregnancies ┆ Glucose ┆ BloodPressu ┆ SkinThickne ┆ … ┆ BodyMassInd ┆ DiabetesPe ┆ Age ┆ Outcome │
# │ ---         ┆ ---     ┆ re          ┆ ss          ┆   ┆ ex          ┆ digreeFunc ┆ --- ┆ ---     │
# │ i64         ┆ i64     ┆ ---         ┆ ---         ┆   ┆ ---         ┆ tion       ┆ i64 ┆ i64     │
# │             ┆         ┆ i64         ┆ i64         ┆   ┆ f64         ┆ ---        ┆     ┆         │
# │             ┆         ┆             ┆             ┆   ┆             ┆ f64        ┆     ┆         │
# ╞═════════════╪═════════╪═════════════╪═════════════╪═══╪═════════════╪════════════╪═════╪═════════╡
# │ 6           ┆ 148     ┆ 72          ┆ 35          ┆ … ┆ 33.6        ┆ 0.627      ┆ 50  ┆ 1       │
# │ 1           ┆ 85      ┆ 66          ┆ 29          ┆ … ┆ 26.6        ┆ 0.351      ┆ 31  ┆ 0       │
# ...

# %%
#Asumir que 'SkinThickness' ha sido eliminado durante la selección de variables (feature selection)
feature_cols = ['Pregnancies', 'Insulin', 'BodyMassIndex', 'Age','Glucose','BloodPressure','DiabetesPedigreeFunction']
X = df.select(feature_cols) # Features
y = df.select("Outcome") # Target

# %%
X_np = X.to_numpy()
y_np = y.to_numpy().ravel() # .ravel() para convertir en un array 1D

# %%
X_np.shape
# Out:
# (768, 7)

# %%
y_np.shape
# Out:
# (768,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_np, y_np, test_size=0.3, random_state=42) # 70% training, 30% test

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (537, 7) (231, 7) (537,) (231,)

# %% [markdown]
# ## Linea base

# %% [markdown]
# ## Optimización de hiper parámetros
